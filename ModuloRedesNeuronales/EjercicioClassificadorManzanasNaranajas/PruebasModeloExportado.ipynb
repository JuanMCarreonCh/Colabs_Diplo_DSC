# %%
import tensorflow as tf
from glob import glob
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import PIL
import cv2

# %%
naranjas_test=list(glob("apple-orange-dataset/test/oranges/*"))

# %%
naranjas_test_imgs = [cv2.resize(cv2.cvtColor(cv2.imread(path),
                                            cv2.COLOR_BGR2RGB),(100,100)) for path in naranjas_test]

# %%
naranjas_test_imgs_cverde = np.array(naranjas_test_imgs[:])[:,:,:,1] / 255

# %%
# !pip install tensorrt
# Out:
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
plt.figure(figsize=(3,3))
plt.imshow(naranjas_test_imgs_cverde[7],cmap='grey')

# %%
plt.figure(figsize=(3,3))
plt.imshow(naranjas_test_imgs[7])

# %%
#Cargamos el modelo
path = '/home/seventhbook/diplo/Colabs_Diplo_DSC/ModuloRedesNeuronales/EjercicioClassificadorManzanasNaranajas/'
model_name = 'modelo_class_oranges_vs_apples.h5'
model = tf.keras.models.load_model(path+model_name)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725128835.019670     918 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1725128835.297188     918 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1725128835.297232     918 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# I0000 00:00:1725128835.299627     918 cuda_executor.cc:1001] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# ...

# %%
naranjas_test_imgs_cverde.shape
# Out:
# (74, 100, 100)

# %%
input_image = np.reshape(naranjas_test_imgs_cverde[0], (1, 100, 100))
prediction = model.predict(input_image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 748ms/step

# %%
prediction
# Out:
# array([[9.22848e-14, 1.00000e+00]], dtype=float32)

# %%
# Out:
# <Sequential name=sequential, built=True>
